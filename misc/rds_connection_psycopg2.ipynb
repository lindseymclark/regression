# %%
#Get a pandas dataframe from Amazon PostgreSQL RDS
#L. Morris September 2019

# %%
import pandas as pd

# %%
import psycopg2
connection = psycopg2.connect(
    host = 'database-2.ciks9ot9g63b.us-east-1.rds.amazonaws.com',
    port = 5432,
    user = 'postgres',
    password = 'mypassword',
    database='postgres'
    )
cursor=connection.cursor()

# %%
def read_sql_file(path):
    rd = open(path, 'r')
    sqlFile = rd.read()
    rd.close
    print(sqlFile)
    return sqlFile

# %%
sqlFile = read_sql_file("/Users/lindseyclark/Desktop/sql_titanic.sql")
# Out:
# select *
# from titanic.titantic_train
# limit 100;

# %%
pd.read_sql(sqlFile, con=connection)
# Out:
#     passengerid  survived  pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...
